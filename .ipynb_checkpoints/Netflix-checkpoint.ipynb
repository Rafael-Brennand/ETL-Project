# %%
import pandas as pd
from sqlalchemy import create_engine
import requests
import json
from pprint import pprint

# %%
url = "http://www.omdbapi.com/?t="
api_key = "&apikey=77d3b433"

# %% [markdown]
# # EXTRACT

# %% [markdown]
# ### Store CSV into DataFrame

# %%
csv_file = "Resources/netflix_titles.csv"
netflix_df = pd.read_csv(csv_file)
netflix_df
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4             Fernando Lebrija
# ...                        ...
# 6229                       NaN
# 6230                       NaN
# 6231                       NaN
# 6232                       NaN
# 6233                       NaN
#
#                                                    cast  \
# 0     Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                      Jandino Asporaat
# 2     Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3     Will Friedle, Darren Criss, Constance Zimmer, ...
# 4     Nesta Cooper, Kate Walsh, John Michael Higgins...
# ...                                                 ...
# 6229  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...
# 6230  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...
# 6231                                                NaN
# 6232  Daniel Radcliffe, Jon Hamm, Adam Godley, Chris...
# 6233  Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...
#
#                                        country         date_added  \
# 0     United States, India, South Korea, China  September 9, 2019
# 1                               United Kingdom  September 9, 2016
# 2                                United States  September 8, 2018
# 3                                United States  September 8, 2018
# 4                                United States  September 8, 2017
# ...                                        ...                ...
# 6229                             United States                NaN
# 6230                             United States                NaN
# 6231                                       NaN                NaN
# 6232                            United Kingdom                NaN
# 6233                             United States                NaN
#
#       release_year    rating    duration  \
# 0             2019     TV-PG      90 min
# 1             2016     TV-MA      94 min
# 2             2013  TV-Y7-FV    1 Season
# 3             2016     TV-Y7    1 Season
# 4             2017     TV-14      99 min
# ...            ...       ...         ...
# 6229          2015        NR  13 Seasons
# 6230          2016     TV-MA   4 Seasons
# 6231          2016       NaN      60 min
# 6232          2013     TV-MA   2 Seasons
# 6233          2003     TV-14  10 Seasons
#
#                                               listed_in  \
# 0                    Children & Family Movies, Comedies
# 1                                       Stand-Up Comedy
# 2                                              Kids' TV
# 3                                              Kids' TV
# 4                                              Comedies
# ...                                                 ...
# 6229  TV Action & Adventure, TV Comedies, TV Sci-Fi ...
# 6230                                        TV Comedies
# 6231                                             Movies
# 6232           British TV Shows, TV Comedies, TV Dramas
# 6233                     Classic & Cult TV, TV Comedies
#
#                                             description
# 0     Before planning an awesome wedding for his gra...
# 1     Jandino Asporaat riffs on the challenges of ra...
# 2     With the help of three human allies, the Autob...
# 3     When a prison ship crash unleashes hundreds of...
# 4     When nerdy high schooler Dani finally attracts...
# ...                                                 ...
# 6229  This parody of first-person shooter games, mil...
# 6230  Marc Maron stars as Marc Maron, who interviews...
# 6231  Nursery rhymes and original music for children...
# 6232  Set during the Russian Revolution, this comic ...
# 6233  This hit sitcom follows the merry misadventure...
#
# [6234 rows x 12 columns]

# %% [markdown]
# # TRANSFORM

# %% [markdown]
# ### Create new data with select columns

# %%
#Filter netflix titles to Movies only
netflix_movies = netflix_df.loc[netflix_df['type'] == 'Movie']
netflix_movies = netflix_movies.loc[netflix_movies['country'] == 'United States']
netflix_movies = netflix_movies[netflix_movies['listed_in']=='Documentaries']
netflix_movies
# Out:
#        show_id   type                                              title  \
# 79    80182115  Movie                                          Long Shot
# 92    81001809  Movie  Lessons from a School Shooting: Notes from Dun...
# 114   80173625  Movie                    Restless Creature: Wendy Whelan
# 115   80005444  Movie                                   Print the Legend
# 123   80198423  Movie                                       Teach Us All
# ...        ...    ...                                                ...
# 5564  70129457  Movie                                           Life 2.0
# 5570  80104318  Movie                                    Silicon Cowboys
# 5572  80097468  Movie                                       The Bad Kids
# 5577  80085438  Movie                                    Frank and Cindy
# 5580  80064521  Movie                Jeremy Scott: The People's Designer
#
#                              director  \
# 79                    Jacob LaMendola
# 92                      Kim A. Snyder
# 114   Linda Saffire, Adam Schlesinger
# 115            Luis Lopez, Clay Tweel
# 123                      Sonia Lowman
# ...                               ...
# 5564              Jason Spingarn-Koff
# 5570                      Jason Cohen
# 5572         Keith Fulton, Louis Pepe
# 5577                 G.J. Echternkamp
# 5580                       Vlad Yudin
#
#                                                    cast        country  \
# 79                                                  NaN  United States
# 92                                                  NaN  United States
# 114   Peter Martins, Sean Suozzi, Gretchen Smith, As...  United States
# 115                                                 NaN  United States
# 123                                                 NaN  United States
# ...                                                 ...            ...
# 5564                                                NaN  United States
# 5570                                                NaN  United States
# 5572                                                NaN  United States
# 5577                                                NaN  United States
# 5580                                       Jeremy Scott  United States
#
#               date_added  release_year rating duration      listed_in  \
# 79    September 29, 2017          2017  TV-14   40 min  Documentaries
# 92    September 28, 2018          2018  TV-PG   24 min  Documentaries
# 114   September 26, 2017          2016  TV-MA   94 min  Documentaries
# 115   September 26, 2014          2014  TV-14  100 min  Documentaries
# 123   September 25, 2017          2017  TV-14   81 min  Documentaries
# ...                  ...           ...    ...      ...            ...
# 5564       April 1, 2017          2010     NR   99 min  Documentaries
# 5570       April 1, 2017          2016  TV-PG   77 min  Documentaries
# 5572       April 1, 2017          2016  TV-MA  101 min  Documentaries
# 5577       April 1, 2016          2007  TV-MA   70 min  Documentaries
# 5580       April 1, 2016          2015  PG-13  109 min  Documentaries
#
#                                             description
# 79    When Juan Catalan is arrested for a murder he ...
# 92    Two priests – one from Dunblane, Scotland, the...
# 114   After 30 years with the New York City Ballet, ...
# 115   This award-winning, original documentary chron...
# 123   It's been decades since Brown v. Board of Educ...
# ...                                                 ...
# 5564  Computer users across the globe log onto the v...
# 5570  This documentary tells the story of Compaq Com...
# 5572  In this documentary, teachers at a Mojave Dese...
# 5577  Frank was a rising pop star when he married Ci...
# 5580  The journey of fashion designer Jeremy Scott f...
#
# [203 rows x 12 columns]

# %%
#pull only select columns from the data
new_netflix_df = netflix_movies[['show_id','title', 'country', 'release_year', 'rating']].copy()
#rename id column
netflix_transformed = new_netflix_df.rename(columns={"show_id": "id"})
netflix_transformed
# Out:
#             id                                              title  \
# 79    80182115                                          Long Shot
# 92    81001809  Lessons from a School Shooting: Notes from Dun...
# 114   80173625                    Restless Creature: Wendy Whelan
# 115   80005444                                   Print the Legend
# 123   80198423                                       Teach Us All
# ...        ...                                                ...
# 5564  70129457                                           Life 2.0
# 5570  80104318                                    Silicon Cowboys
# 5572  80097468                                       The Bad Kids
# 5577  80085438                                    Frank and Cindy
# 5580  80064521                Jeremy Scott: The People's Designer
#
#             country  release_year rating
# 79    United States          2017  TV-14
# 92    United States          2018  TV-PG
# 114   United States          2016  TV-MA
# 115   United States          2014  TV-14
# 123   United States          2017  TV-14
# ...             ...           ...    ...
# 5564  United States          2010     NR
# 5570  United States          2016  TV-PG
# 5572  United States          2016  TV-MA
# 5577  United States          2007  TV-MA
# 5580  United States          2015  PG-13
#
# [203 rows x 5 columns]

# %% [markdown]
# ### API OMBDB

# %%
imdb_rating = []
meta_rating = []
awards =[]
not_found = 0
found_movies = []
movies = netflix_transformed['title']

for movie in movies:
    response = requests.get (url + movie + api_key)
    omdb = response.json()
    try:
        imdb_rating.append(omdb["imdbRating"])
        meta_rating.append(omdb["Metascore"])
        awards.append(omdb["Awards"])
        found_movies.append(movie)
    except:
        not_found = not_found + 1
        pass

# %%
#Create dataframe from information acquired from API
omdb_df = pd.DataFrame(list(zip(found_movies, imdb_rating, meta_rating, awards)),columns = ["Movie_Title", "IMDB_Rating", "Metacritic_Rating", "Awards"])
omdb_df = omdb_df[omdb_df!="N/A"].dropna()
omdb_df
# Out:
#                   Movie_Title IMDB_Rating Metacritic_Rating  \
# 2                    Automata         6.1                37
# 7                        Love         6.1                51
# 10             Rolling Papers         6.2                60
# 11         Stonehearst Asylum         6.8                52
# 13                    6 Years         5.6                53
# 17  Sierra Burgess Is A Loser         5.8                60
#
#                     Awards
# 2           6 nominations.
# 7   2 wins & 1 nomination.
# 10                  1 win.
# 11   1 win & 1 nomination.
# 13          4 nominations.
# 17          2 nominations.

# %% [markdown]
# ### Connect to local database

# %%
rds_connection_string = "postgres:ged436Ruw@localhost:5432/netflix_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %% [markdown]
# ### Check for tables

# %%
engine.table_names()
# Out:
# ['netflix_movies']

# %% [markdown]
# # LOAD

# %% [markdown]
# ### Use pandas to load netflix_titles.csv converted DataFrame into database

# %%
netflix_transformed.to_sql(name='netflix_movies', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# StringDataRightTruncation                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                 if not evt_handled:
# -> 1257                     self.dialect.do_executemany(
#    1258                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# StringDataRightTruncation: value too long for type character(1)
#
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# <ipython-input-11-80700650e019> in <module>
# ----> 1 netflix_transformed.to_sql(name='netflix_movies', con=engine, if_exists='append', index=False)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2651         from pandas.io import sql
#    2652
# -> 2653         sql.to_sql(
#    2654             self,
#    2655             name,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     510         )
#     511
# --> 512     pandas_sql.to_sql(
#     513         frame,
#     514         name,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#    1012             )
#    1013         else:
# -> 1014             return meth(self, multiparams, params)
#    1015
#    1016     def _execute_function(self, func, multiparams, params):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1125             )
#    1126
# -> 1127         ret = self._execute_context(
#    1128             dialect,
#    1129             dialect.execution_ctx_cls._init_compiled,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315
#    1316         except BaseException as e:
# -> 1317             self._handle_dbapi_exception(
#    1318                 e, statement, parameters, cursor, context
#    1319             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1510             elif should_wrap:
# -> 1511                 util.raise_(
#    1512                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1513                 )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                             break
#    1256                 if not evt_handled:
# -> 1257                     self.dialect.do_executemany(
#    1258                         cursor, statement, parameters, context
#    1259                     )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     871     def do_executemany(self, cursor, statement, parameters, context=None):
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#     875
#
# DataError: (psycopg2.errors.StringDataRightTruncation) value too long for type character(1)
#
# [SQL: INSERT INTO netflix_movies (id, title, country, release_year, rating) VALUES (%(id)s, %(title)s, %(country)s, %(release_year)s, %(rating)s)]
# [parameters: ({'id': 81145628, 'title': 'Norm of the North: King Sized Adventure', 'country': 'United States, India, South Korea, China', 'release_year': 2019, 'rating': 'TV-PG'}, {'id': 80117401, 'title': 'Jandino: Whatever it Takes', 'country': 'United Kingdom', 'release_year': 2016, 'rating': 'TV-MA'}, {'id': 80125979, 'title': '#realityhigh', 'country': 'United States', 'release_year': 2017, 'rating': 'TV-14'}, {'id': 70304989, 'title': 'Automata', 'country': 'Bulgaria, United States, Spain, Canada', 'release_year': 2014, 'rating': 'R'}, {'id': 80164077, 'title': 'Fabrizio Copano: Solo pienso en mi', 'country': 'Chile', 'release_year': 2017, 'rating': 'TV-MA'}, {'id': 70304990, 'title': 'Good People', 'country': 'United States, United Kingdom, Denmark, Sweden', 'release_year': 2014, 'rating': 'R'}, {'id': 80169755, 'title': 'Joaquín Reyes: Una y no más', 'country': None, 'release_year': 2017, 'rating': 'TV-MA'}, {'id': 70299204, 'title': 'Kidnapping Mr. Heineken', 'country': 'Netherlands, Belgium, United Kingdom, United States', 'release_year': 2015, 'rating': 'R'}  ... displaying 10 of 4265 total bound parameter sets ...  {'id': 80064521, 'title': "Jeremy Scott: The People's Designer", 'country': 'United States', 'release_year': 2015, 'rating': 'PG-13'}, {'id': 80116008, 'title': 'Little Baby Bum: Nursery Rhyme Friends', 'country': None, 'release_year': 2016, 'rating': None})]
# (Background on this error at: http://sqlalche.me/e/13/9h9h)

# %% [markdown]
# ### Confirm data has been added by querying the customer_location table

# %%
pd.read_sql_query('select * from netflix_movies', con=engine).head()
# Out:
#          id                                    title  \
# 0  81145628  Norm of the North: King Sized Adventure
# 1  80117401               Jandino: Whatever it Takes
# 2  80125979                             #realityhigh
# 3  70304989                                 Automata
# 4  80164077       Fabrizio Copano: Solo pienso en mi
#
#                                     country  release_year rating
# 0  United States, India, South Korea, China          2019  TV-PG
# 1                            United Kingdom          2016  TV-MA
# 2                             United States          2017  TV-14
# 3    Bulgaria, United States, Spain, Canada          2014      R
# 4                                     Chile          2017  TV-MA

# %% [markdown]
# ### Use pandas to load OMDb API converted DataFrame into database
